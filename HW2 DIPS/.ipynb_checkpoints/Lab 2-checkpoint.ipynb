# %% [markdown]
# # Question 1
#
# ### Part A)
# Obtain the unnormalized and the normalized histograms of the following 8-bit, MXN
# image. Give your histogram as a table and a graph, labeling clearly the value and location
# of each histogram component in terms of M and N. Double-check your answer by making
# sure that the histogram components add to the correct value.
#
# Row x Column
#
# ![image.png](attachment:12d09003-800f-4fac-bc60-23c933b68988.png)

# %% [markdown]
# #### Unnormalized
#
# There are 8 values present in the image which are:
# 240, 127, 16, 191, 228, 32, 225, 0
#
# The unnormalized histogram of the picture above is as follows:

# %% [markdown]
# ![image-6.png](attachment:image-6.png)
#
# ![image-5.png](attachment:image-5.png)

# %% [markdown]
# #### Normalized
#
# Using the same 8 values and frequency from before we are going to find the normalized form using the following function on all the frequencies:
#
# $$Norm = \frac{Pixel Occurences}{Total Occurences}$$

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# Pixel Values      Frequency     Location (M, N) => (0, 0):(3, 4)
# 0                 2             (1, 2), (1, 3), (2, 2), (2, 3)
# 16                1             (0, 1), (1, 1)
# 32                1             (0, 2), (0, 3)
# 127               1             (2, 0)
# 191               1             (2, 1)
# 225               1             (0, 3), (1, 3)
# 228               1             (0, 2), (1, 2)
# 255               1             (0, 0), (1, 0)
#
# Pixel Values      Frequency     Location (M, N) => (0, 0):(3, 4)
# 0                 0.222         (1, 2), (1, 3), (2, 2), (2, 3)
# 16                0.111         (0, 1), (1, 1)
# 32                0.111         (0, 2), (0, 3)
# 127               0.111         (2, 0)
# 191               0.111         (2, 1)
# 225               0.111         (0, 3), (1, 3)
# 228               0.111         (0, 2), (1, 2)
# 255               0.111         (0, 0), (1, 0)

# %% [markdown]
# Showing that the frequencies are correct and not normalized improperly
# $$7(\frac{1}{9}) + \frac{2}{9}=1$$

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Question 1
# ### Part B)
#
# ![image.png](attachment:image.png)

# %% [markdown]
# No, the blurred image histograms would not be the same as there would be different values generated through the filter. As the filters would be exposed to averages that wouldnt be seen in the other image.
#
# If we assumed that both images were an 8x8 then we would end up with intensity values as follows:

# %% [markdown]
# ![image.png](attachment:image.png)
# The matrix on the left is blurred image A and the matrix on the right is blurred image B
#
#
# As you can see there are different values in both blurred image which would result in a different histogram

# %% [markdown]
# # Question 2
# ### Part A)
#
# ![image.png](attachment:image.png)

# %% [markdown]
# i)
# ![image.png](attachment:image.png)
# 2, 17, 18, 21, 22, 24, 32, 88, 122
#
# The median is 22
#
# ii)
# ![image-2.png](attachment:image-2.png)
# 12, 75, 92, 100, 112, 138, 140, 142, 144
#
# The median is 112
#
# iii)
# ![image-3.png](attachment:image-3.png)
# 5, 7, 12, 12, 17, 21, 22, 32, 88
#
# The median is 17
#
# iv)
# ![image-4.png](attachment:image-4.png)
# 88, 92, 100, 104, 104, 107, 112, 133, 155
#
# The median is 104

# %% [markdown]
# ### Part B)
#
# ![image.png](attachment:image.png)

# %% [markdown]
# The image will start off in the following array:
# $$\begin{bmatrix} 10 & 20 \\ 30 & 40 \end{bmatrix}$$
#
# Then transform to something as such:
# $$\begin{bmatrix} 10 & ? & 20 \\ ? & ? & ? \\ 30 & ? & 40 \end{bmatrix}$$
# From here we need to find the missing values which will be the middle of the adjacent values with the exception of the central coordinate
#
# $$\begin{bmatrix} 10 & 15 & 20 \\ 20 & ? & 30 \\ 30 & 35 & 40 \end{bmatrix}$$
#
# From here we need to use bilinear interpolation to find the central coordinate and use the following formulas and end with the following matrix:

# %% [markdown]
# # Question 3
#
# We are given the following image histogram:
#
# |Gray Value|Number of Pixels|
# |:--------:|:--------:|
# |0|10|
# |1|5|
# |2|5|
# |3|11|
# |4|5|
# |5|0|
# |6|3|
# |7|6|
#
# This is the specificed histogram
#
# |Gray Value|Number of Pixels|
# |:--------:|:--------:|
# |0|5|
# |1|5|
# |2|5|
# |3|10|
# |4|10|
# |5|5|
# |6|5|
# |7|0|
#
# Total Number: 45
#
#
# From here we do the following so that we can map later
#
# Image Hist.
# |Gray Value|Number of Pixels|PDF|CDF|SKx7|Round Off|New nk.|
# |:--------:|:--------:|:--------:|:--------:|:--------:|:--------:|:------:|
# |0|10| 0.22|0.22|1.54|2|0
# |1|5| 0.11|0.33|2.31|2|0
# |2|5| 0.11|0.44|3.08|3|15
# |3|11| 0.24|0.68|4.76|5|5
# |4|5| 0.11|0.79|5.53|6|11
# |5|0| 0|0.79|5.53|6|5
# |6|3| 0.07|0.86|6.02|6|3
# |7|6| 0.13|0.99|6.93|7|6
#
# Specified Hist.
# |Gray Value|Number of Pixels|PDF|CDF|SKx7|Round Off|
# |:--------:|:--------:|:--------:|:--------:|:--------:|:--------:|
# |0|5| 0.11|0.77||1|
# |1|5| 0.11|0.22|1.54|2|
# |2|5| 0.11|0.33|2.31|2|
# |3|10| 0.22|0.55|3.85|4|
# |4|10| 0.22|0.77|5.39|5|
# |5|5| 0.11|0.88|6.16|6|
# |6|5| 0.11|0.99|6.93|7|
# |7|0| 0|0.99|6.93|7|

# %% [markdown]
# |Gray Level|Number of Pixels|
# |:--------:|:--------------:|
# |0|0|
# |1|15|
# |2|15|
# |3|0|
# |4|5|
# |5|3|
# |6|6|
# |7|6|

# %% [markdown]
# # Question 4
#
# ### Part A)

# %% [markdown]
# # Question 4
#
# ### Part B)
